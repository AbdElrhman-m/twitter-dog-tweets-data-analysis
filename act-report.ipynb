# %% [markdown]
#    # labrador retriever image gets 813685 favorites/likes on twitter!!
#
# <img src="https://pbs.twimg.com/ext_tw_video_thumb/744234667679821824/pu/img/1GaWmtJtdqzZV7jy.jpg" alt="dog" width="300"/>
# The WeRateDogs Twitter archive contains basic tweet data for all 5000+ of their tweets, but not everything. One column the archive does contain though: each tweet's text, which I used to extract rating, dog name, and dog "stage" (i.e. doggo, floofer, pupper, and puppo) to make this Twitter archive "enhanced." Of the 5000+ tweets, I have filtered for tweets with ratings only (there are 2066 ).
#
#  ![dog_Stag](dog_Stag.png)
#
#  More than **60%** of dog tweets about **pupper** dogs, more than **30%** about **doggo**.
#  The pupper dogs should be the most popular on twitter!
#  ![download.png](attachment:download.png)
#  however, the average rating of pupper tweets is 1.07 which is the lowest average rate.
#  ### if we take a look at the tweets dog bread we can see:
#  ![breads](breads.png)
#  The golden retriever bread has about 150 tweets sharing their photos, as it's really large number because the next largest one is Labrador retriever with only 100 tweets from 2066 tweet.
#
#  ### if we take a look on the retweets source:
#  ![scoure.png](attachment:scoure.png)
#  the largest number of retweets source is twitter for iPhone (about 3 million retweets) with is more than 98% of the total numbers of retweets.
#     # labrador retriever image gets 813685 favorites/likes on twitter!!
#
# <img src="https://pbs.twimg.com/ext_tw_video_thumb/744234667679821824/pu/img/1GaWmtJtdqzZV7jy.jpg" alt="dog" width="300"/>
# The WeRateDogs Twitter archive contains basic tweet data for all 5000+ of their tweets, but not everything. One column the archive does contain though: each tweet's text, which I used to extract rating, dog name, and dog "stage" (i.e. doggo, floofer, pupper, and puppo) to make this Twitter archive "enhanced." Of the 5000+ tweets, I have filtered for tweets with ratings only (there are 2066 ).
#
#  ![dog_Stag](dog_Stag.png)
#
#  More than **60%** of dog tweets about **pupper** dogs, more than **30%** about **doggo**.
#  The pupper dogs should be the most popular on Twitter!
#  ![download.png](attachment:download.png)
#  however the average rating of pupper tweets is 1.07 which is the lowest average rate.
#  ### if we take a look on the tweets dog breads we can see:
#  ![breads](breads.png)
#  The golden retriever bread have about 150 tweets sharing there photos, as it's realy larg number beacuse the next largest one is labrador retriever with only 100 tweets from 2066 tweet.
#
#  ### if we take a look on the retweets source:
#  ![scoure.png](attachment:scoure.png)
#  the lagest number of retweets source is twitter for iphone (about 3 million retweet) with is more than 98% from the total numbers of retweets.
#  ts.
